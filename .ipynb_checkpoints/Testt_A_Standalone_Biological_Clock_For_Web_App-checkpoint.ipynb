# %%
import os
from my_package import BiologicalAgeClock

model_path='gb_bio_age_clock_pipeline.joblib'
if not os.path.exists(model_path):
            raise FileNotFoundError(f"Model file not found at {model_path}. Verify path configuration.")

# Instantiate your web clock manager
clock = BiologicalAgeClock()

# Mock JSON request data mapping payload from an API request
mock_api_payload = {
    'RIDAGEYR': 52,     # 52 years old
    'RIAGENDR': 2,      # Female
    'BMXBMI': 24.1,     # BMI
    'BPXOPLS1': 68,     # Resting Heart Rate
    'PAD675': 60,       # 60 minutes of daily activity
    'LBXGLU': 92.5,     # Glucose
    'LBXIN': 5.1,       # Insulin
    'LBXHSCRP': 0.08,   # hs-CRP
    'LBXGH': 5.1        # HbA1c
}

# Run prediction
api_response = clock.predict(mock_api_payload)
print(api_response)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 9
#       6             raise FileNotFoundError(f"Model file not found at {model_path}. Verify path configuration.")
#       8 # Instantiate your web clock manager
# ----> 9 clock = BiologicalAgeClock()
#      11 # Mock JSON request data mapping payload from an API request
#      12 mock_api_payload = {
#      13     'RIDAGEYR': 52,     # 52 years old
#      14     'RIAGENDR': 2,      # Female
#    (...)     21     'LBXGH': 5.1        # HbA1c
#      22 }
#
# TypeError: 'module' object is not callable

# %%
from my_package.BiologicalAgeClock import BiologicalAgeClock

# %%
clock = BiologicalAgeClock(model_path='gb_bio_age_clock_pipeline.joblib')

# %%
# Instantiate your web clock manager
clock = BiologicalAgeClock(model_path='gb_bio_age_clock_pipeline.joblib')

# Mock JSON request data mapping payload from an API request
mock_api_payload = {
    'RIDAGEYR': 52,     # 52 years old
    'RIAGENDR': 2,      # Female
    'BMXBMI': 24.1,     # BMI
    'BPXOPLS1': 68,     # Resting Heart Rate
    'PAD675': 60,       # 60 minutes of daily activity
    'LBXGLU': 92.5,     # Glucose
    'LBXIN': 5.1,       # Insulin
    'LBXHSCRP': 0.08,   # hs-CRP
    'LBXGH': 5.1        # HbA1c
}

# Run prediction
api_response = clock.predict(mock_api_payload)
print(api_response)
# Out:
# {'chronological_age': 52, 'predicted_biological_age': 44.16, 'age_acceleration_gap': -7.84, 'aging_status': 'Decelerated', 'calculated_vo2_max_proxy': 22.87}
